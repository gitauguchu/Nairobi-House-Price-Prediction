# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('buy_rent_kenya.csv')

# %%
df.head(10)
# Out:
#                                       Title  \
# 0    4 Bed House with En Suite in Hill View
# 1        4 Bed House with En Suite in Runda
# 2                   4 Bed House in Muthaiga
# 3        5 Bed House with En Suite in Runda
# 4        5 Bed House with En Suite in Runda
# 5   5 Bed House with En Suite at Runda Road
# 6                   4 Bed House in Kitisuru
# 7                   4 Bed House in Kitisuru
# 8  4 Bed House with En Suite at Peponi Road
# 9        4 Bed House with En Suite at Runda
#
#                                 Location  No of bedrooms  No of bathrooms  \
# 0                   Hill View, Westlands               4              2.0
# 1                       Runda, Westlands               4              5.0
# 2                               Muthaiga               4              NaN
# 3                       Runda, Westlands               5              NaN
# 4                       Runda, Westlands               5              6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1242 non-null   object
#  1   Location         1242 non-null   object
#  2   No of bedrooms   1242 non-null   int64
#  3   No of bathrooms  1104 non-null   float64
#  4   Description      1242 non-null   object
#  5   Price            1242 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 58.3+ KB

# %%
df.describe()
# Out:
#        No of bedrooms  No of bathrooms
# count     1242.000000      1104.000000
# mean         4.444444         4.187500
# std          0.896167         1.184743
# min          3.000000         2.000000
# 25%          4.000000         3.750000
# 50%          4.000000         4.000000
# 75%          5.000000         5.000000
# max          7.000000         6.000000

# %%
df.columns
# Out:
# Index(['Title', 'Location', 'No of bedrooms', 'No of bathrooms', 'Description',
#        'Price'],
#       dtype='object')

# %%
df['No of bathrooms'].fillna(4, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1242 non-null   object
#  1   Location         1242 non-null   object
#  2   No of bedrooms   1242 non-null   int64
#  3   No of bathrooms  1242 non-null   float64
#  4   Description      1242 non-null   object
#  5   Price            1242 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 58.3+ KB

# %%
df.head(10)
# Out:
#                                       Title  \
# 0    4 Bed House with En Suite in Hill View
# 1        4 Bed House with En Suite in Runda
# 2                   4 Bed House in Muthaiga
# 3        5 Bed House with En Suite in Runda
# 4        5 Bed House with En Suite in Runda
# 5   5 Bed House with En Suite at Runda Road
# 6                   4 Bed House in Kitisuru
# 7                   4 Bed House in Kitisuru
# 8  4 Bed House with En Suite at Peponi Road
# 9        4 Bed House with En Suite at Runda
#
#                                 Location  No of bedrooms  No of bathrooms  \
# 0                   Hill View, Westlands               4              2.0
# 1                       Runda, Westlands               4              5.0
# 2                               Muthaiga               4              4.0
# 3                       Runda, Westlands               5              4.0
# 4                       Runda, Westlands               5              6.0
# ...

# %%
df['Price'] = df['Price'].str.replace(',', '')

# %%
df['Price'] = df['Price'].str.extract(r'(\d+[\.,]?\d*)').astype(float)

# %%
df.head(10)
# Out:
#                                       Title  \
# 0    4 Bed House with En Suite in Hill View
# 1        4 Bed House with En Suite in Runda
# 2                   4 Bed House in Muthaiga
# 3        5 Bed House with En Suite in Runda
# 4        5 Bed House with En Suite in Runda
# 5   5 Bed House with En Suite at Runda Road
# 6                   4 Bed House in Kitisuru
# 7                   4 Bed House in Kitisuru
# 8  4 Bed House with En Suite at Peponi Road
# 9        4 Bed House with En Suite at Runda
#
#                                 Location  No of bedrooms  No of bathrooms  \
# 0                   Hill View, Westlands               4              2.0
# 1                       Runda, Westlands               4              5.0
# 2                               Muthaiga               4              4.0
# 3                       Runda, Westlands               5              4.0
# 4                       Runda, Westlands               5              6.0
# ...

# %%
df.describe()
# Out:
#        No of bedrooms  No of bathrooms          Price
# count     1242.000000      1242.000000    1173.000000
# mean         4.444444         4.166667  355588.235294
# std          0.896167         1.118484  122573.353804
# min          3.000000         2.000000  110000.000000
# 25%          4.000000         4.000000  295000.000000
# 50%          4.000000         4.000000  340000.000000
# 75%          5.000000         5.000000  450000.000000
# max          7.000000         6.000000  550000.000000

# %%
df['Price'].fillna(355558, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1242 non-null   object
#  1   Location         1242 non-null   object
#  2   No of bedrooms   1242 non-null   int64
#  3   No of bathrooms  1242 non-null   float64
#  4   Description      1242 non-null   object
#  5   Price            1242 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 58.3+ KB

# %%
df.head(10)
# Out:
#                                       Title  \
# 0    4 Bed House with En Suite in Hill View
# 1        4 Bed House with En Suite in Runda
# 2                   4 Bed House in Muthaiga
# 3        5 Bed House with En Suite in Runda
# 4        5 Bed House with En Suite in Runda
# 5   5 Bed House with En Suite at Runda Road
# 6                   4 Bed House in Kitisuru
# 7                   4 Bed House in Kitisuru
# 8  4 Bed House with En Suite at Peponi Road
# 9        4 Bed House with En Suite at Runda
#
#                                 Location  No of bedrooms  No of bathrooms  \
# 0                   Hill View, Westlands               4              2.0
# 1                       Runda, Westlands               4              5.0
# 2                               Muthaiga               4              4.0
# 3                       Runda, Westlands               5              4.0
# 4                       Runda, Westlands               5              6.0
# ...

# %%
df['Location'].value_counts()
# Out:
# Location
# Runda, Westlands                         276
# Kitisuru, Westlands                      138
# Kileleshwa                               138
# Karen                                    138
# Hill View, Westlands                      69
# Muthaiga                                  69
# Runda Road, Runda, Westlands              69
# Peponi road, Spring Valley, Westlands     69
# 01, Runda, Gigiri, Westlands              69
# 01, Runda, Westlands                      69
# Lavington                                 69
# Kiambu Road                               69
# Name: count, dtype: int64

# %%
pd.get_dummies(df['Location'])
# Out:
#       01, Runda, Gigiri, Westlands  01, Runda, Westlands  \
# 0                            False                 False
# 1                            False                 False
# 2                            False                 False
# 3                            False                 False
# 4                            False                 False
# ...                            ...                   ...
# 1237                         False                 False
# 1238                         False                 False
# 1239                         False                 False
# 1240                         False                 False
# 1241                         False                 False
#
#       Hill View, Westlands  Karen  Kiambu Road  Kileleshwa  \
# 0                     True  False        False       False
# 1                    False  False        False       False
# 2                    False  False        False       False
# ...

# %%
data = df.join(pd.get_dummies(df['Location']))
data
# Out:
#                                          Title              Location  \
# 0       4 Bed House with En Suite in Hill View  Hill View, Westlands
# 1           4 Bed House with En Suite in Runda      Runda, Westlands
# 2                      4 Bed House in Muthaiga              Muthaiga
# 3           5 Bed House with En Suite in Runda      Runda, Westlands
# 4           5 Bed House with En Suite in Runda      Runda, Westlands
# ...                                        ...                   ...
# 1237    7 Bed House with En Suite at Lavington             Lavington
# 1238   5 Bed Villa with En Suite in Kileleshwa            Kileleshwa
# 1239  4 Bed House with En Suite in Kiambu Road           Kiambu Road
# 1240    6 Bed Townhouse with En Suite in Karen                 Karen
# 1241          3 Bed House with Garden in Karen                 Karen
#
#       No of bedrooms  No of bathrooms  \
# 0                  4              2.0
# 1                  4              5.0
# ...

# %%
data.drop('Location', axis=1, inplace=True)

# %%
data
# Out:
#                                          Title  No of bedrooms  \
# 0       4 Bed House with En Suite in Hill View               4
# 1           4 Bed House with En Suite in Runda               4
# 2                      4 Bed House in Muthaiga               4
# 3           5 Bed House with En Suite in Runda               5
# 4           5 Bed House with En Suite in Runda               5
# ...                                        ...             ...
# 1237    7 Bed House with En Suite at Lavington               7
# 1238   5 Bed Villa with En Suite in Kileleshwa               5
# 1239  4 Bed House with En Suite in Kiambu Road               4
# 1240    6 Bed Townhouse with En Suite in Karen               6
# 1241          3 Bed House with Garden in Karen               3
#
#       No of bathrooms                                        Description  \
# 0                 2.0       For Rent: 4 Bedroom House in Hillview Estate
# ...

# %%
X = data.drop(['Title', 'Description', 'Price'], axis=1)
y = data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
train_data = X_train.join(y_train)

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'No of bedrooms'}>,
#         <Axes: title={'center': 'No of bathrooms'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %%
sns.distplot(train_data['Price'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3480\3469573845.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_data['Price'])
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.heatmap(train_data.corr())
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)
plt.xlabel('y_test')
plt.ylabel('predictions')
# Out:
# Text(0, 0.5, 'predictions')

# %%
from sklearn import metrics
print('MAE: ', metrics.mean_absolute_error(y_test,predictions))
print('MSE: ', metrics.mean_squared_error(y_test,predictions))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE:  16744.49565969225
# MSE:  751184544.446636
# RMSE:  27407.746066516233
